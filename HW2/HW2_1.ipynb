# %% [markdown]
# <a href="https://colab.research.google.com/github/Bbuyukyilmaz/ELE492---Image-Processing-Homeworks/blob/main/HW2/HW2_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Description : This code was written by Barış Büyükyılmaz for ELE492 first homework.

from skimage import io

img = io.imread("dog.jpg")      # Read image
io.imshow(img)                  # Show image
